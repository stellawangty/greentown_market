# %% [markdown]
# <a href="https://colab.research.google.com/github/stellawangty/greentown_market/blob/master/test_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import Google Drive 套件
from google.colab import drive
# 將自己的雲端硬碟掛載上去
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !fuser /dev/nvidia0

# %%
# !kill `ps|grep python3`
# !kill `fuser /dev/nvidia*`

# %%
# !nvidia-smi
# Out:
# Thu Jul  7 01:44:34 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## 一、复现原数据集测试结果

# %%
# %cd /content/
# !git clone https://github.com/zoogzog/chexnet.git
# !cp /content/gdrive/MyDrive/DL/cnn/CheXNet/chexnet/*.py chexnet/
# !rm chexnet/database -r
# !ln -s /content/ /content/chexnet
# !mv /content/chexnet/content /content/chexnet/database
# Out:
# /content
# Cloning into 'chexnet'...
# remote: Enumerating objects: 26, done.
# remote: Total 26 (delta 0), reused 0 (delta 0), pack-reused 26
# Unpacking objects: 100% (26/26), done.

# %%
# !python /content/chexnet/batch_download_zips.py
# Out:
# downloadingimages_01.tar.gz...
# downloadingimages_02.tar.gz...
# downloadingimages_03.tar.gz...
# downloadingimages_04.tar.gz...
# downloadingimages_05.tar.gz...
# downloadingimages_06.tar.gz...
# downloadingimages_07.tar.gz...
# downloadingimages_08.tar.gz...
# downloadingimages_09.tar.gz...
# downloadingimages_10.tar.gz...
# downloadingimages_11.tar.gz...
# downloadingimages_12.tar.gz...
# Download complete. Please check the checksums

# %%
# !tar -xzvf images_01.tar.gz
# !mkdir images_001/
# !mv images/* images_001/

# !tar -xzvf images_02.tar.gz
# !mkdir images_002/
# !mv images/* images_002/

# !tar -xzvf images_03.tar.gz
# !mkdir images_003/
# !mv images/* images_003/

# !tar -xzvf images_04.tar.gz
# !mkdir images_004/
# !mv images/* images_004/

# !tar -xzvf images_05.tar.gz
# !mkdir images_005/
# !mv images/* images_005/

# !tar -xzvf images_06.tar.gz
# !mkdir images_006/
# !mv images/* images_006/

# !tar -xzvf images_07.tar.gz
# !mkdir images_007/
# !mv images/* images_007/

# !tar -xzvf images_08.tar.gz
# !mkdir images_008/
# !mv images/* images_008/

# !tar -xzvf images_09.tar.gz
# !mkdir images_009/
# !mv images/* images_009/

# !tar -xzvf images_10.tar.gz
# !mkdir images_010/
# !mv images/* images_010/

# !tar -xzvf images_11.tar.gz
# !mkdir images_011/
# !mv images/* images_011/

# !tar -xzvf images_12.tar.gz
# !mkdir images_012/
# !mv images/* images_012/

# !rm images/ -r

# %%
# %cd /content/chexnet
# !python Main.py
# Out:
# /content/chexnet
# AUROC mean  0.8508467326447381
# Atelectasis   0.8321114003170667
# Cardiomegaly   0.9106581893835491
# Effusion   0.8860258067915978
# Infiltration   0.7145122403471709
# Mass   0.865300647663563
# Nodule   0.8036829733048876
# Pneumonia   0.7655152803738839
# Pneumothorax   0.8856667783532476
# Consolidation   0.8156658751340223
# Edema   0.9017088251270582
# Emphysema   0.9422342731400383
# Fibrosis   0.8523217762064218
# Pleural_Thickening   0.7948250481287641
# Hernia   0.9416251427550609

# %%
# 打包代码
# !cp *.py /content/gdrive/MyDrive/DL/cnn/CheXNet/chexnet/

# %% [markdown]
# 结果：把源代码适配版本（源代码是不同torch和sklearn版本，适配到当前版本），多gpu改成单gpu，使用作者的pretrained预测测试集，acc接近

# %% [markdown]
# ## 二、测试

# %%
# !python /content/chexnet/batch_download_zips.py
# Out:
# downloadingimages_01.tar.gz...
# downloadingimages_02.tar.gz...
# Traceback (most recent call last):
#   File "/content/chexnet/batch_download_zips.py", line 24, in <module>
#     urllib.request.urlretrieve(link, fn)  # download the zip file
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/http/client.py", line 465, in read
#     n = self.readinto(b)
#   File "/usr/lib/python3.7/http/client.py", line 509, in readinto
#     n = self.fp.readinto(b)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.7/ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.7/ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt

# %%
# !tar -xzvf images_01.tar.gz
# Out:
# images/00001075_000.png
# images/00001151_006.png
# images/00000583_047.png
# images/00000830_002.png
# images/00001232_004.png
# images/00000245_001.png
# images/00000089_000.png
# images/00000911_000.png
# images/00000811_000.png
# images/00001213_002.png
# images/00001057_001.png
# images/00000949_004.png
# images/00000869_009.png
# images/00000731_005.png
# images/00000121_007.png
# images/00001088_021.png
# images/00000631_005.png
# images/00000116_015.png
# images/00000459_053.png
# images/00001286_001.png
# images/00000556_002.png
# images/00000308_000.png
# images/00000127_002.png
# images/00000047_007.png
# images/00000637_000.png
# images/00001039_002.png
# images/00000208_000.png
# images/00000376_007.png
# images/00000103_008.png
# images/00000966_000.png
# images/00000785_002.png
# images/00001187_004.png
# images/00000537_000.png
# images/00000063_000.png
# images/00000866_000.png
# images/00001268_002.png
# images/00001301_040.png
# images/00000538_003.png
# ...

# %%
# !pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.0 MB 14.9 MB/s
# ...

# %%
import pydicom
import matplotlib.pyplot as plt 
file=r"/content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/COVID-19-AR/COVID-19-AR-16406488/02-14-2012-NA-CT PE CHEST-63916/2.000000-locator-16446/1-1.dcm"
file=r"/content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/COVID-19-AR/COVID-19-AR-16445151/03-08-2012-NA-XR CHEST AP PORTABLE-51919/1.000000-AP-45634/1-1.dcm"
file=r"/content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/COVID-19-AR/COVID-19-AR-16434395/03-03-2012-NA-XR CHEST AP PORTABLE-54576/1.000000-AP-50475/1-1.dcm"
file=r"/content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/COVID-19-AR/COVID-19-AR-16406545/01-17-2012-NA-XR CHEST AP PORTABLE-43479/1.000000-AP-36614/1-1.dcm"
ds = pydicom.dcmread(file)
# plt.figure(figsize=(10, 10))
# plt.imshow(ds.pixel_array, cmap=plt.cm.bone)
ds.pixel_array.shape
# Out:
# (2330, 2846)

# %% [markdown]
# ## 三、构建、分割数据集

# %%
# !cp /content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/COVID-19-AR/ ./ -r
# !cp /content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/metadata.csv ./
# !cp "/content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/COVID-19 AR Clinical Correlates July202020.xlsx" ./

# %%
# Import需要的套件
import os
import numpy as np
import cv2
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt 
plt.rcParams["figure.figsize"] = (30,15)
import numpy as np
import pandas as pd
import os
import time

from PIL import Image
import gc
import shutil


def readfiles(path):
    image_dirs=[]
    for fpathe,dirs,fs in os.walk(path):
        for f in fs:
            image_dirs.append(os.path.join(fpathe,f))
    return image_dirs

# %%
# split PMS and others
# %cd /content
metadata=pd.read_csv('metadata.csv')
clinical=pd.read_excel(r'COVID-19 AR Clinical Correlates July202020.xlsx')
SubjectIDtoICUAdmit=dict(zip(clinical['PATIENT_ID'], clinical['ICU Admit']))


dataDic_PMS={}
dataDic_others={}
for index, row in metadata.iterrows():
  SOPClassName=row['SOP Class Name']
  # if 'x-ray' in SOPClassName.lower():
  if True:
    SubjectID=row['Subject ID']
    label=SubjectIDtoICUAdmit[SubjectID]
    Manufacturer=row['Manufacturer']
    nums=row['Number of Images']
    path=row['File Location']
    path=path.replace('\\','/')
    files=readfiles(path)
    files=[f for f in files if f.endswith('.dcm')]
    if len(files)!=nums:
      print("len(files)!=nums")
      print('csv_nums: ',nums,', actual_nums: ',len(files))
      print(files)
    # if Manufacturer == "Philips Medical Systems":
    if Manufacturer == "Philips":
      l=dataDic_PMS.get(label,[])
      l+=files
      dataDic_PMS[label]=l
    else:
      l=dataDic_others.get(label,[])
      l+=files
      dataDic_others[label]=l

dataPaths=[]
num_labels=[]
labels=list(dataDic_PMS.keys())
print("labels: ",labels)
for k in dataDic_PMS.keys():
  dataPaths+=dataDic_PMS[k]
  lb=labels.index(k)
  num_labels+=[lb for _ in range(len(dataDic_PMS[k]))]

with open('labels.txt','w',encoding='utf-8') as f:
  f.write('\n'.join(labels))

train_str_list=[]
for i in range(len(dataPaths)):
    train_str_list.append('%s------%d'%(dataPaths[i], num_labels[i]))
with open('PMS_dataset_all.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(train_str_list))

dataPaths=[]
num_labels=[]
labels=list(dataDic_others.keys())
print("labels: ",labels)
for k in dataDic_others.keys():
  dataPaths+=dataDic_others[k]
  lb=labels.index(k)
  num_labels+=[lb for _ in range(len(dataDic_others[k]))]

with open('labels.txt','w',encoding='utf-8') as f:
  f.write('\n'.join(labels))

train_str_list=[]
for i in range(len(dataPaths)):
    train_str_list.append('%s------%d'%(dataPaths[i], num_labels[i]))
with open('others_dataset_all.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(train_str_list))

dataPaths=[]
num_labels=[]
labels=list(dataDic_PMS.keys())
print("labels: ",labels)
for k in dataDic_PMS.keys():
  dataPaths+=dataDic_PMS[k]
  lb=labels.index(k)
  num_labels+=[lb for _ in range(len(dataDic_PMS[k]))]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test  = train_test_split(dataPaths, num_labels, test_size=0.2)
print("PMS")
print("all:   ",[num_labels.count(v) for v in range(len(labels))])
print("train: ",[y_train.count(v) for v in range(len(labels))])
print("val:   ",[y_test.count(v) for v in range(len(labels))])

# with open('labels.txt','w',encoding='utf-8') as f:
#   f.write('\n'.join(labels))

train_str_list=[]
for i in range(len(x_train)):
    train_str_list.append('%s------%d'%(x_train[i], y_train[i]))
with open('PMS_dataset_train.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(train_str_list))

test_str_list=[]
for i in range(len(x_test)):
    test_str_list.append('%s------%d'%(x_test[i], y_test[i]))
with open('PMS_dataset_val.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(test_str_list))

dataPaths=[]
num_labels=[]
labels=list(dataDic_others.keys())
print("labels: ",labels)
for k in dataDic_others.keys():
  dataPaths+=dataDic_others[k]
  lb=labels.index(k)
  num_labels+=[lb for _ in range(len(dataDic_others[k]))]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test  = train_test_split(dataPaths, num_labels, test_size=0.2)
print("others")
print("all:   ",[num_labels.count(v) for v in range(len(labels))])
print("train: ",[y_train.count(v) for v in range(len(labels))])
print("val:   ",[y_test.count(v) for v in range(len(labels))])

# with open('labels.txt','w',encoding='utf-8') as f:
#   f.write('\n'.join(labels))

train_str_list=[]
for i in range(len(x_train)):
    train_str_list.append('%s------%d'%(x_train[i], y_train[i]))
with open('others_dataset_train.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(train_str_list))

test_str_list=[]
for i in range(len(x_test)):
    test_str_list.append('%s------%d'%(x_test[i], y_test[i]))
with open('others_dataset_val.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(test_str_list))
# Out:
# /content
# labels:  ['N', 'Y']
# labels:  ['N', 'Y']
# labels:  ['N', 'Y']
# PMS
# all:    [20197, 8513]
# train:  [16099, 6869]
# val:    [4098, 1644]
# labels:  ['N', 'Y']
# others
# all:    [2090, 1135]
# train:  [1689, 891]
# val:    [401, 244]

# %%
# %cd /content
# !cp *.txt /content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/dataset
# Out:
# /content

# %%
# split all
# %cd /content
metadata=pd.read_csv('metadata.csv')
clinical=pd.read_excel(r'COVID-19 AR Clinical Correlates July202020.xlsx')
SubjectIDtoICUAdmit=dict(zip(clinical['PATIENT_ID'], clinical['ICU Admit']))


dataDic={}

for index, row in metadata.iterrows():
  SOPClassName=row['SOP Class Name']
  if 'x-ray' in SOPClassName.lower():
  # if True:
    SubjectID=row['Subject ID']
    label=SubjectIDtoICUAdmit[SubjectID]
    nums=row['Number of Images']
    path=row['File Location']
    path=path.replace('\\','/')
    files=readfiles(path)
    files=[f for f in files if f.endswith('.dcm')]
    if len(files)!=nums:
      print("len(files)!=nums")
      print('csv_nums: ',nums,', actual_nums: ',len(files))
      print(files)
    l=dataDic.get(label,[])
    l+=files
    dataDic[label]=l
# Out:
# /content

# %%
# x-ray
for k in dataDic.keys():
  print("%s: %d"%(k, len(dataDic[k])))
# Out:
# N: 134
# Y: 102

# %%
dataPaths=[]
num_labels=[]
labels=list(dataDic.keys())
print("labels: ",labels)
for k in dataDic.keys():
  dataPaths+=dataDic[k]
  lb=labels.index(k)
  num_labels+=[lb for _ in range(len(dataDic[k]))]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test  = train_test_split(dataPaths, num_labels, test_size=0.25)
print("all:   ",[num_labels.count(v) for v in range(len(labels))])
print("train: ",[y_train.count(v) for v in range(len(labels))])
print("val:   ",[y_test.count(v) for v in range(len(labels))])

with open('labels.txt','w',encoding='utf-8') as f:
  f.write('\n'.join(labels))

train_str_list=[]
for i in range(len(x_train)):
    train_str_list.append('%s------%d'%(x_train[i], y_train[i]))
with open('train.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(train_str_list))

test_str_list=[]
for i in range(len(x_test)):
    test_str_list.append('%s------%d'%(x_test[i], y_test[i]))
with open('val.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(test_str_list))
# Out:
# labels:  ['N', 'Y']
# all:    [134, 102]
# train:  [97, 80]
# val:    [37, 22]

# %%
# all
for k in dataDic.keys():
  print("%s: %d"%(k, len(dataDic[k])))
# Out:
# N: 22287
# Y: 9648

# %%
dataPaths=[]
num_labels=[]
labels=list(dataDic.keys())
print("labels: ",labels)
for k in dataDic.keys():
  dataPaths+=dataDic[k]
  lb=labels.index(k)
  num_labels+=[lb for _ in range(len(dataDic[k]))]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test  = train_test_split(dataPaths, num_labels, test_size=0.25)
print("all:   ",[num_labels.count(v) for v in range(len(labels))])
print("train: ",[y_train.count(v) for v in range(len(labels))])
print("val:   ",[y_test.count(v) for v in range(len(labels))])

with open('labels.txt','w',encoding='utf-8') as f:
  f.write('\n'.join(labels))

train_str_list=[]
for i in range(len(x_train)):
    train_str_list.append('%s------%d'%(x_train[i], y_train[i]))
with open('train.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(train_str_list))

test_str_list=[]
for i in range(len(x_test)):
    test_str_list.append('%s------%d'%(x_test[i], y_test[i]))
with open('val.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(test_str_list))
# Out:
# labels:  ['N', 'Y']
# all:    [22287, 9648]
# train:  [16664, 7287]
# val:    [5623, 2361]

# %%
# !mkdir /content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/dataset/
# !cp train.txt val.txt labels.txt /content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/dataset/

# %% [markdown]
# ## 四、尝试训练

# %%
# 构建自己的代码
# !pip install pydicom
# 处理医疗影像的Python利器PyDicom: https://zhuanlan.zhihu.com/p/59413289
# %cd /content/
# !git clone https://github.com/zoogzog/chexnet.git
# !cp /content/gdrive/MyDrive/DL/cnn/CheXNet/chexnet/*.py chexnet/
# !rm /content/chexnet/dataset/ -r
# !cp /content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/dataset/ /content/chexnet/ -r

# # 复制数据集
# !cp /content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/COVID-19-AR/ ./ -r
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.0 MB 8.2 MB/s
# ...
# /content
# Cloning into 'chexnet'...
# remote: Enumerating objects: 26, done.
# remote: Total 26 (delta 0), reused 0 (delta 0), pack-reused 26
# Unpacking objects: 100% (26/26), done.

# %%
import time
while True:
  time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-6a5d71f3542c> in <module>()
#       1 import time
#       2 while True:
# ----> 3   time.sleep(1)
#
# KeyboardInterrupt:

# %%
# train on Philips others
# %cd /content/chexnet
# !python Main.py
# Out:
# /content/chexnet
# Loss in epoch 0 :::: lossTrain: 0.2898880558801286 with lr: 0.0005
#                      lossVal: 0.3853266721680051
#         acc: 0.8
#            0            1
#        0.988        0.492
# Loss in epoch 1 :::: lossTrain: 0.18444873604141634 with lr: 0.0005
#                      lossVal: 0.2810397488453115
#         acc: 0.9007751937984496
#            0            1
#        0.903        0.898
# Loss in epoch 2 :::: lossTrain: 0.13988049900918095 with lr: 0.0005
#                      lossVal: 0.23057322823331647
#         acc: 0.9038759689922481
#            0            1
#        0.950        0.828
# Loss in epoch 3 :::: lossTrain: 0.18375364755406792 with lr: 0.0005
#                      lossVal: 0.2067117499453681
#         acc: 0.9116279069767442
#            0            1
#        0.985        0.791
# Loss in epoch 4 :::: lossTrain: 0.14627441782274364 with lr: 0.0005
#                      lossVal: 0.11455152299077738
# ...

# %%
# train on Philips
# %cd /content/chexnet
# !python Main.py
# Out:
# /content/chexnet
# Loss in epoch 0 :::: lossTrain: 0.42992284808899367 with lr: 0.0005
#                      lossVal: 0.4575631383392546
#         acc: 0.7821316614420063
#            0            1
#        0.791        0.761
# Loss in epoch 1 :::: lossTrain: 0.3419236905125688 with lr: 0.0005
#                      lossVal: 0.306206466174788
#         acc: 0.8749564611633577
#            0            1
#        0.912        0.783
# Loss in epoch 2 :::: lossTrain: 0.2929392662054981 with lr: 0.0005
#                      lossVal: 0.2629529047343466
#         acc: 0.88662486938349
#            0            1
#        0.965        0.692
# Loss in epoch 3 :::: lossTrain: 0.2575144921961269 with lr: 0.0005
#                      lossVal: 0.25038793823785255
#         acc: 0.8949843260188087
#            0            1
#        0.925        0.821
# Loss in epoch 4 :::: lossTrain: 0.23479430505118662 with lr: 0.0005
#                      lossVal: 0.20665400330391195
# ...

# %%
# train on all COVID-19 AR Clinical Correlates July202020
# %cd /content/chexnet
# !python Main.py
# Out:
# /content/chexnet
# Loss in epoch 0 :::: lossTrain: 0.5210157886286763 with lr: 0.0005
#                      lossVal: 0.49668916434049604
#         acc: 0.7920841683366734
#            0            1
#        0.841        0.676
# Loss in epoch 1 :::: lossTrain: 0.4196985403948696 with lr: 0.0005
#                      lossVal: 0.39065743988752366
#         acc: 0.842560120240481
#            0            1
#        0.900        0.706
# Loss in epoch 2 :::: lossTrain: 0.3611070665124262 with lr: 0.0005
#                      lossVal: 0.34195992624759675
#         acc: 0.843812625250501
#            0            1
#        0.855        0.817
# Loss in epoch 3 :::: lossTrain: 0.3262858416074427 with lr: 0.0005
#                      lossVal: 0.33317373669147493
#         acc: 0.8617234468937875
#            0            1
#        0.875        0.830
# Loss in epoch 4 :::: lossTrain: 0.29830394356010437 with lr: 0.0005
#                      lossVal: 0.27518080776929854
# ...

# %%
# 打包代码和数据集分布
# %cd /content/chexnet
# !cp *.py /content/gdrive/MyDrive/DL/cnn/CheXNet/chexnet/
# !cp -r /content/chexnet/dataset /content/gdrive/MyDrive/Dataset2/COVID-19-AR/manifest-1594658036421/
# Out:
# /content/chexnet

# %% [markdown]
# ## 五、尝试测试

# %%
# train on Philips test on Philips
# %cd /content/chexnet
# !python Main.py
# Out:
# /content/chexnet
#                      lossVal: 0.09673114287317901
#         acc: 0.9608150470219435
#            0            1
#        0.989        0.890
# outAUROC:
# 0.937333682444347

# %%
# train on Philips test on others
# %cd /content/chexnet
# !python Main.py
# Out:
# /content/chexnet
#                      lossVal: 4.597088991123953
#         acc: 0.6232558139534884
#            0            1
#        0.988        0.025
# outAUROC:
# 0.5076652630718286

# %%
# train on others test on others
# %cd /content/chexnet
# !python Main.py
# Out:
# /content/chexnet
#                      lossVal: 0.07784668525678565
#         acc: 0.9612403100775194
#            0            1
#        0.980        0.930
# outAUROC:
# 0.945745267977597

# %%
# train on others test on Philips
# %cd /content/chexnet
# !python Main.py
# Out:
# /content/chexnet
#                      lossVal: 1.236755750180951
#         acc: 0.5640891675374434
#            0            1
#        0.600        0.475
# outAUROC:
# 0.537680388866921
